# %%
from gpcam import GPOptimizer
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ## gp2Scale

# %%
import dask
from dask.distributed import Client
import os
import time

scheduler_file = os.path.join(os.environ["SCRATCH"], "scheduler_file_gpOmol.json")
dask.config.config["distributed"]["dashboard"]["link"] = "{JUPYTERHUB_SERVICE_PREFIX}proxy/{host}:{port}/status" 

while True:
    time.sleep(2)
    if os.path.isfile(scheduler_file):
        print("file found")
        time.sleep(1)
        client = Client(scheduler_file=scheduler_file)
        break
print("waiting for workers")
client.wait_for_workers(16)
print(client)

# %%
hps = np.array([9.80873959e-02, 5.59217926e+00, 9.71443068e-01, 1.29018807e+01,
 8.06507594e+00, 1.28293582e+01, 2.60715969e+03])

hps_bounds = hyperparameter_bounds()

my_gp1 = GPOptimizer(x_train,y_train,
                     init_hyperparameters = hps,
                     noise_variances=np.ones(y_train_sub.shape) * 0.001, 
                     compute_device='gpu', 
                     kernel_function=battery_kernel_gpu, 
                     gp2Scale = True,
                     gp2Scale_batch_size=10000,
                     dask_client=client,
                     linalg_mode='sparseLU',
                     )
print("ML: ", my_gp1.log_likelihood())

# %%
import time
st = time.time()
print("hps bounds: ")
print(hps_bounds)
print("Standard Training (MCMC)")
hps = my_gp1.train(hyperparameter_bounds=hps_bounds, info = True, max_iter = 100, 
                   init_hyperparameters=hps)
print("Result=", hps, "after ", time.time() - st, " seconds")
print("")

# %%
## posterior predictions

# %%
x_test1 = x_test[0:1000]
y_test1 = y_test[0:1000]

# %%
mean = my_gp1.posterior_mean([pickle.dumps(x, protocol=4) for x in x_test1])["m(x)"]

# %%
sd = np.sqrt(my_gp1.posterior_covariance([pickle.dumps(x, protocol=4) for x in x_test1], variance_only=True)["v(x)"])
